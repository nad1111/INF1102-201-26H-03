# %%
"""
╔══════════════════════════════════════════════════════════════╗
║          🪐 RAPPORT D'INSTALLATION JUPYTERLAB               ║
║                                                              ║
║  Étudiant: 300143951                                         ║
║  Cours: INF1102-201-26H-03                                   ║
║  Date: 20 janvier 2026                                       ║
╚══════════════════════════════════════════════════════════════╝
"""

import sys
import platform
import jupyter_core

# ═══════════════════════════════════════════════════════════════
# 📦 ÉTAPE 1: Installation Miniforge
# ═══════════════════════════════════════════════════════════════

print("\n┌─────────────────────────────────────────────────┐")
print("│  1️⃣  INSTALLATION MINIFORGE                    │")
print("└─────────────────────────────────────────────────┘")
print("""
Commande:
  → choco install miniforge3 -y

Problème rencontré:
  ⚠️  Erreur de permissions Windows

Solution:
  ✅ PowerShell en mode administrateur
  ✅ Suppression du fichier de verrouillage
""")

# ═══════════════════════════════════════════════════════════════
# ⚙️  ÉTAPE 2: Configuration de l'environnement
# ═══════════════════════════════════════════════════════════════

print("\n┌─────────────────────────────────────────────────┐")
print("│  2️⃣  CONFIGURATION CONDA                       │")
print("└─────────────────────────────────────────────────┘")
print("""
Commandes:
  → conda init powershell
  → conda create -n INF1102 python=3.12 -y
  → conda activate INF1102

Résultat:
  ✅ Environnement virtuel Python 3.12 créé
""")

# ═══════════════════════════════════════════════════════════════
# 🪐 ÉTAPE 3: Installation JupyterLab
# ═══════════════════════════════════════════════════════════════

print("\n┌─────────────────────────────────────────────────┐")
print("│  3️⃣  JUPYTERLAB                                │")
print("└─────────────────────────────────────────────────┘")
print("""
Installation:
  → conda install -c conda-forge jupyterlab -y

Lancement:
  → jupyter lab

Authentification:
  🔐 Utilisation du token généré dans le terminal
  🌐 http://localhost:8888/lab?token=...
""")

# ═══════════════════════════════════════════════════════════════
# 🔄 ÉTAPE 4: Intégration Git
# ═══════════════════════════════════════════════════════════════

print("\n┌─────────────────────────────────────────────────┐")
print("│  4️⃣  GIT & GITHUB                              │")
print("└─────────────────────────────────────────────────┘")
print("""
Workflow:
  → git add .
  → git commit -m 'jupyter fonctionne'
  → git pull && git push

Conflit résolu:
  ⚠️  Participation.md modifié par plusieurs étudiants
  ✅ git checkout --theirs pour accepter version distante
""")

# ═══════════════════════════════════════════════════════════════
# ✅ VÉRIFICATION SYSTÈME
# ═══════════════════════════════════════════════════════════════

print("\n" + "═" * 55)
print("              🔍 VÉRIFICATION SYSTÈME")
print("═" * 55)

verif = {
    "Python": sys.version.split()[0],
    "Jupyter": jupyter_core.__version__,
    "OS": f"{platform.system()} {platform.release()}",
    "Environnement": "INF1102",
    "Statut": "✅ OPÉRATIONNEL"
}

for cle, valeur in verif.items():
    print(f"  {cle:15s} │ {valeur}")

print("═" * 55)

# ═══════════════════════════════════════════════════════════════
# 🎯 CONCLUSION
# ═══════════════════════════════════════════════════════════════

print(f"""
{'─' * 55}
                    🎓 CONCLUSION
{'─' * 55}

Installation complète de JupyterLab réussie.

Défis surmontés:
  • Permissions Windows
  • Configuration PATH PowerShell
  • Authentification par token
  • Conflits Git en environnement collaboratif

Premier notebook créé et synchronisé avec GitHub.

{'═' * 55}
""")
# Out:
# ┌─────────────────────────────────────────────────┐
# │  1️⃣  INSTALLATION MINIFORGE                    │
# └─────────────────────────────────────────────────┘
#
# Commande:
#   → choco install miniforge3 -y
#
# Problème rencontré:
#   ⚠️  Erreur de permissions Windows
#
# Solution:
#   ✅ PowerShell en mode administrateur
#   ✅ Suppression du fichier de verrouillage
#
#
# ┌─────────────────────────────────────────────────┐
# │  2️⃣  CONFIGURATION CONDA                       │
# └─────────────────────────────────────────────────┘
#
# Commandes:
#   → conda init powershell
#   → conda create -n INF1102 python=3.12 -y
#   → conda activate INF1102
#
# Résultat:
#   ✅ Environnement virtuel Python 3.12 créé
#
#
# ┌─────────────────────────────────────────────────┐
# │  3️⃣  JUPYTERLAB                                │
# └─────────────────────────────────────────────────┘
#
# Installation:
#   → conda install -c conda-forge jupyterlab -y
#
# Lancement:
#   → jupyter lab
#
# ...
