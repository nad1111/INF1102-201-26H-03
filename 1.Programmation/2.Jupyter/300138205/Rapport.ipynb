# %% [markdown]
# # 300138205

# %%
print("Bienvenu dans le groupe 3")
# Out:
# Bienvenu dans le groupe 3

# %% [markdown]
# # Une fonction

# %%
a = [1, 2, 3, 4]
f = sum(a)
print(f)
# Out:
# 10

# %% [markdown]
# # une fonction

# %% [markdown]
# $f = \sum_{i=1}^{n} a(i)$

# %% [markdown]
# $f_i = \sum_{k=1}^{i} a_k$
