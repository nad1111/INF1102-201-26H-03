# %% [markdown]
# # TP de participation – Jupyter et Miniforge
#
# **Nom :** Amel
# **Cours :** INF1102 – Programmation
# **Système :** Windows

# %% [markdown]
# ## Objectif du TP
#
# L’objectif de ce TP est d’installer Jupyter à l’aide de Chocolatey et Miniforge sous Windows, puis de vérifier le bon fonctionnement de l’environnement Python à l’aide de JupyterLab.

# %% [markdown]
# ## Installation de Miniforge
#
# Miniforge a été installé à l’aide de Chocolatey avec la commande suivante :
# choco install miniforge3 -y

# %% [markdown]
# Cette installation permet d’utiliser Conda pour gérer des environnements Python.

# %%
print("Jupyter fonctionne correctement ✅")
# Out:
# Jupyter fonctionne correctement ✅

# %%
x = 10
y = 20
print(x + y)
# Out:
# 30

# %% [markdown]
# ## Conclusion
#
# Ce TP m’a permis d’installer et de configurer correctement JupyterLab à l’aide de Miniforge et Conda sous Windows.
# L’environnement Python fonctionne correctement et permet l’exécution de code Python dans un notebook.
