# %%
# 🪐 Jupyter – Participation

**Nom :** Nour Miri  
**Matricule :** 300138573  
**Cours :** INF1102  

Installation de JupyterLab avec Miniforge et Chocolatey sous Windows PowerShell.
# Out:
#   Cell In[5], line 3
#     **Nom :** Nour Miri
#     ^
# SyntaxError: invalid syntax

# %%
print("Hello INF1102 👋 Jupyter fonctionne parfaitement !")
# Out:
# Hello INF1102 👋 Jupyter fonctionne parfaitement !
